# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv(Path.home()/'dragon_tydamin.train_metrics.csv')

# %%
df
# Out:
#     Train Acc  Train Acc Raw    Train Loss  Test Acc  Test Acc Raw
# 0    0.773508       0.773508  7.707058e+12  0.764421      0.764421  \
# 1    0.782473       0.782473  4.265230e+05  0.772874      0.772874
# 2    0.798082       0.798058  4.802117e-03  0.791550      0.791479
# 3    0.802369       0.802369  4.613303e-03  0.797528      0.797528
# 4    0.807630       0.807544  4.502980e-03  0.802702      0.802665
# 5    0.803917       0.803917  4.320988e-03  0.798272      0.798272
# 6    0.807751       0.807741  4.212101e-03  0.802685      0.802685
# 7    0.814645       0.814645  4.206353e-03  0.810390      0.810388
# 8    0.809955       0.809955  4.188001e-03  0.805919      0.805919
# 9    0.809821       0.809806  4.061313e-03  0.805538      0.805529
# 10   0.812772       0.812772  4.089570e-03  0.808044      0.808044
# 11   0.811330       0.811315  4.075953e-03  0.806553      0.806543
#
#        Test Loss
# 0   18783.062759
# 1   16310.686913
# 2     642.101140
# 3       0.026550
# ...

# %%
df.plot(y=['Train Acc','Test Acc'])
# Out:
# <Axes: >

# %%
df.plot(y=['Train Loss'],#, 'Test Loss'],
    ylim=(0, 0.01))
# Out:
# <Axes: >
