# %%
from pathlib import Path
import pandas as pd
# pd.set_option('display.max_colwidth', 20)   # JSON columns make things look weird in notebook without this

# %%
# !ls ~/evals/bool_debug
# Out:
# args.pickle		astera-temp-e927d.lock~  debug_vars.csv
# astera-temp-e927d.gpr	astera-temp-e927d.rep
# astera-temp-e927d.lock	binary_paths.csv

# %%
folder = Path.home()/'evals/bool_debug'
dbg = pd.read_csv(folder/'debug_vars.csv')
dbg
# Out:
#        BinaryId  FunctionStart       Signature Vartype        Name
# 0             6        1081344             NaN       p         ctx  \
# 1             6        1081344           20,26       l       iVar1
# 2             6        1089216              40       p     param_1
# 3             6        1089216              40       p     param_2
# 4             6        1089216              17       l   auStack_8
# ...         ...            ...             ...     ...         ...
# 18510         6        1766138             NaN       l  guid_local
# 18511         6        1766160           25,44       p     param_1
# 18512         6        1766160              73       p     param_2
# 18513         6        1766160              73       p     param_3
# 18514         6        1766160  55,73,77,77,81       l       lVar1
#
#                   Location           Type             TypeJson
# 0      LocType=register...  EVP_PKEY_CTX*  {"kind": "Pointe...
# 1      LocType=register...          int32  {"kind": "Builti...
# 2      LocType=register...         uint64  {"kind": "Builti...
# 3               Stack[0x0]         uint64  {"kind": "Builti...
# 4              Stack[-0x8]       uchar[8]  {"kind": "ArrayT...
# ...                    ...            ...                  ...
# 18510         Stack[-0x10]          char*  {"kind": "Pointe...
# 18511  LocType=register...  EVP_PKEY_CTX*  {"kind": "Pointe...
# 18512  LocType=register...         uint64  {"kind": "Builti...
# 18513  LocType=register...         uint64  {"kind": "Builti...
# 18514  LocType=register...          int64  {"kind": "Builti...
#
# [18515 rows x 8 columns]

# %%
dbg[dbg.Type=='bool'].TypeJson
# Out:
# 151      {"kind": "Builti...
# 528      {"kind": "Builti...
# 547      {"kind": "Builti...
# 683      {"kind": "Builti...
# 1300     {"kind": "Builti...
# 1878     {"kind": "Builti...
# 2561     {"kind": "Builti...
# 2683     {"kind": "Builti...
# 2827     {"kind": "Builti...
# 2833     {"kind": "Builti...
# 2839     {"kind": "Builti...
# 2948     {"kind": "Builti...
# 3901     {"kind": "Builti...
# 3957     {"kind": "Builti...
# 3979     {"kind": "Builti...
# 4022     {"kind": "Builti...
# 5980     {"kind": "Builti...
# 6414     {"kind": "Builti...
# 6892     {"kind": "Builti...
# 7395     {"kind": "Builti...
# 7422     {"kind": "Builti...
# 7538     {"kind": "Builti...
# 8447     {"kind": "Builti...
# 8869     {"kind": "Builti...
# 8876     {"kind": "Builti...
# 9183     {"kind": "Builti...
# 9403     {"kind": "Builti...
# 9410     {"kind": "Builti...
# 10406    {"kind": "Builti...
# 10881    {"kind": "Builti...
# 11692    {"kind": "Builti...
# 11693    {"kind": "Builti...
# 11694    {"kind": "Builti...
# 12288    {"kind": "Builti...
# 12325    {"kind": "Builti...
# 15352    {"kind": "Builti...
# 15353    {"kind": "Builti...
# 16204    {"kind": "Builti...
# 18009    {"kind": "Builti...
# Name: TypeJson, dtype: object
