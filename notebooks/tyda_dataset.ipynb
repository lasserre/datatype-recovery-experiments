# %%
#!ls ~

# %%
import json
from pathlib import Path
import pandas as pd

json_file = Path.home()/'C_CPP_binaries_O0.json'

with open(json_file, 'r') as f:
    data = json.load(f)

# %%
list(data.keys())[:25]
# Out:
# ['dev-libs/cJSON-1.7.15/libcjson.so.1.7.15',
#  'dev-libs/libtecla-1.6.3/enhance',
#  'dev-libs/nettle-3.7.3/pkcs1-conv',
#  'dev-libs/pmdk-1.9.2/daxio',
#  'dev-libs/satyr-0.39/satyr',
#  'dev-libs/nettle-3.7.3/nettle-pbkdf2',
#  'dev-libs/tree-sitter-python-0.19.1_p20211112/libtree-sitter-python.so.13',
#  'dev-libs/pmdk-1.9.2/rpmemd',
#  'dev-libs/libwacom-1.12/libwacom-list-devices',
#  'dev-libs/pmdk-1.9.2/pmempool',
#  'dev-libs/libwacom-1.12/libwacom-list-local-devices',
#  'dev-libs/nettle-3.7.3/nettle-lfib-stream',
#  'dev-libs/nettle-3.7.3/nettle-hash',
#  'dev-libs/nettle-3.7.3/sexp-conv',
#  'dev-libs/libffi-3.4.2-r1/libffi.so.8.1.0',
#  'dev-libs/libmodbus-3.1.6/libmodbus.so.5.1.0',
#  'dev-libs/libwacom-1.12/libwacom.so.2.6.1',
#  'dev-libs/libtar-1.2.20-r4/libtar',
#  'dev-libs/libserialport-0.1.1-r1/libserialport.so.0.1.0',
#  'dev-libs/libtecla-1.6.3/libtecla.so.1.6.3',
#  'dev-libs/liblognorm-2.0.6/lognormalizer',
#  'dev-libs/libtecla-1.6.3/libtecla_r.so.1.6.3',
#  'dev-libs/pmdk-1.9.2/librpmem.so.1.0.0',
#  'dev-libs/botan-2.19.1/botan',
#  'dev-libs/libax25-0.0.12_rc5/libax25io.so.0.0.0']

# %%
k = list(data.keys())[0]
data[k]
# Out:
# {'dwarf_info': 'yes',
#  'stripped': 'no',
#  'language': 'C',
#  'O_flag': ['-O0'],
#  'inlined_func': 'no',
#  'hash': '5af209fb7c21e61e80aba905d4788b1b',
#  'x86-64': 'yes',
#  'cython': 'no'}

# %%
f"{len([k for k in data if data[k]['stripped']=='no'])/len(data)*100}% of binaries are not stripped"
# Out:
# '99.99390113743787% of binaries are not stripped'

# %%
langs = [data[k]['language'] for k in data]
# len([x for x in langs if x == 'CPP'])
# len([x for x in langs if x == 'C'])
# len([x for x in langs if x == 'both'])

df = pd.DataFrame(data).transpose().reset_index().rename({'index': 'binary'}, axis=1)
df['Opt'] = df.O_flag.apply(lambda x: ','.join(x))

# %%
df.groupby('language').count()['binary']
# Out:
# language
# C       22493
# CPP      9169
# both     1131
# Name: binary, dtype: int64

# %%
# calculate target N binaries before we filter out unwanted cases
N = int(len(df)*.08)
N
# Out:
# 2623

# %%
# keep only debug bins
df = df[df.dwarf_info=='yes']
df = df[df.stripped=='no']
df = df[df.language=='C']
df = df[df.Opt=='-O0']

# %%
print(f'Filtered out {int(N/.08)-len(df):,} binaries')
df
# Out:
# Filtered out 11,653 binaries
#                                           binary dwarf_info stripped language
# 0       dev-libs/cJSON-1.7.15/libcjson.so.1.7.15        yes       no        C  \
# 1                dev-libs/libtecla-1.6.3/enhance        yes       no        C
# 2               dev-libs/nettle-3.7.3/pkcs1-conv        yes       no        C
# 4                      dev-libs/satyr-0.39/satyr        yes       no        C
# 5            dev-libs/nettle-3.7.3/nettle-pbkdf2        yes       no        C
# ...                                          ...        ...      ...      ...
# 32780         dev-erlang/esip-1.0.45/esip_drv.so        yes       no        C
# 32785   dev-erlang/fast_yaml-1.0.32/fast_yaml.so        yes       no        C
# 32786  dev-erlang/fast_xml-1.1.48/fxml_stream.so        yes       no        C
# 32789                dev-erlang/eimp-1.0.21/eimp        yes       no        C
# 32791     dev-erlang/fast_tls-1.1.13/fast_tls.so        yes       no        C
#
#       O_flag inlined_func                              hash x86-64 cython  Opt
# 0      [-O0]           no  5af209fb7c21e61e80aba905d4788b1b    yes     no  -O0
# 1      [-O0]           no  809eb422c5367fbf4527e7b4f7e95de5    yes     no  -O0
# 2      [-O0]           no  a71c58c9694c00e24bb5708a6222d626    yes     no  -O0
# 4      [-O0]           no  7d34e12083bcf0aa2beeb14f2eec68b9    yes     no  -O0
# 5      [-O0]           no  65388dfea1edb19fd9174312062342c2    yes     no  -O0
# ...      ...          ...                               ...    ...    ...  ...
# 32780  [-O0]           no  21383d15270ca5b911ea5fc833e74c88    yes     no  -O0
# 32785  [-O0]           no  cbecd9c132a82e512db00a8bf7fc59ab    yes     no  -O0
# 32786  [-O0]           no  8f499ef065c604c6723746df90da7082    yes     no  -O0
# 32789  [-O0]           no  5bae5bdf4ebe701ddfce2aa03603e072    yes     no  -O0
# 32791  [-O0]           no  2a01958668a5a1e0044f3b42ba17d28e    yes     no  -O0
#
# [21134 rows x 10 columns]

# %%
#df.sample(frac=0.08)

# this should approximate the TyDA-min 8% of binaries
df.sample(n=N)
# Out:
#                                                   binary dwarf_info stripped
# 10392  media-plugins/gst-transcoder-1.14.1-r1/libgstt...        yes       no  \
# 11346  dev-python/pyproj-3.3.1/_datadir.cpython-39-x8...        yes       no
# 4969                       sys-libs/tdb-1.4.5/tdbrestore        yes       no
# 18497   media-video/vlc-3.0.17.3-r2/libswscale_plugin.so        yes       no
# 13956                        net-mail/qmrtg-2.1-r2/qfilt        yes       no
# ...                                                  ...        ...      ...
# 7912                      media-libs/libpulse-16.0/pacat        yes       no
# 12877                      dev-lang/lua-5.3.6-r2/luac5.3        yes       no
# 17019                     app-arch/unadf-0.7.12-r1/unadf        yes       no
# 8415              sys-block/libzbc-5.5.1/libzbc-5.5.1.so        yes       no
# 23284               sys-process/watchpid-0.1-r2/watchpid        yes       no
#
#       language O_flag inlined_func                              hash x86-64
# 10392        C  [-O0]           no  e760d87637f0a14950d35e87c2a7f40e    yes  \
# 11346        C  [-O0]           no  f09f6052be9a24f08ad056b81fe5bc6f    yes
# 4969         C  [-O0]           no  c22f2f7c62f66c2277c2af9cd15fc790    yes
# 18497        C  [-O0]           no  494a0e08e1b75591f8acc76b60ba8e1e    yes
# 13956        C  [-O0]           no  d7fcb627b48150221554dcc54572d3d3    yes
# ...        ...    ...          ...                               ...    ...
# 7912         C  [-O0]           no  7526dd3cc9122fbd859c3bdd86fd136d    yes
# 12877        C  [-O0]           no  481ca7b686eb48f035e9b4ffff8e72a8    yes
# 17019        C  [-O0]           no  8c6ef6a6cd66e33346256c43df636bfa    yes
# 8415         C  [-O0]           no  8939418ecc286a95f862665a5f558bff    yes
# 23284        C  [-O0]           no  c44ed981ed3e993808b8c43a990d1f1b    yes
#
#       cython  Opt
# 10392     no  -O0
# 11346    yes  -O0
# 4969      no  -O0
# 18497     no  -O0
# 13956     no  -O0
# ...      ...  ...
# 7912      no  -O0
# 12877     no  -O0
# 17019     no  -O0
# 8415      no  -O0
# 23284     no  -O0
#
# [2623 rows x 10 columns]

# %%
df.sample(3)
# Out:
#                                            binary dwarf_info stripped
# 31122  media-radio/ax25-tools-0.0.10_rc5/rsmemsiz        yes       no  \
# 26170   sys-cluster/pmix-2.1.1/mca_preg_native.so        yes       no
# 7719          media-libs/netpbm-10.86.30/pbmtopi3        yes       no
#
#       language O_flag inlined_func                              hash x86-64
# 31122        C  [-O0]           no  fc5c92ae337cf0e30f4b686f8532a1e5    yes  \
# 26170        C  [-O0]          yes  364b608e445d9a36c19d991ff2263695    yes
# 7719         C  [-O0]           no  e96e7b57401240ef2a3117e9e6353dc7    yes
#
#       cython  Opt
# 31122     no  -O0
# 26170     no  -O0
# 7719      no  -O0

# %%
df[df.binary.apply(lambda x: 'dev-games' in x)]
# Out:
#                                                   binary dwarf_info stripped
# 28548                   dev-games/libnw-1.30.02/nwresext        yes       no  \
# 28549                   dev-games/libnw-1.30.02/nwstrref        yes       no
# 28550                    dev-games/libnw-1.30.02/nwtsfix        yes       no
# 28551                   dev-games/libnw-1.30.02/nwaggext        yes       no
# 28552                  dev-games/libnw-1.30.02/nw2da2csv        yes       no
# 28553                  dev-games/libnw-1.30.02/nwareamap        yes       no
# 28554                   dev-games/libnw-1.30.02/nwmrgplc        yes       no
# 28555                  dev-games/libnw-1.30.02/nwtsmerge        yes       no
# 28556                   dev-games/libnw-1.30.02/nwtsrefs        yes       no
# 28557                     dev-games/libnw-1.30.02/itpdis        yes       no
# 28558                 dev-games/libnw-1.30.02/plistcheck        yes       no
# 28559  dev-games/freecell-solver-6.6.0/freecell-solve...        yes       no
# 28560  dev-games/freecell-solver-6.6.0/pi-make-micros...        yes       no
# 28561           dev-games/freecell-solver-6.6.0/fc-solve        yes       no
# 28562  dev-games/freecell-solver-6.6.0/freecell-solve...        yes       no
# 28563  dev-games/freecell-solver-6.6.0/freecell-solve...        yes       no
# 28564  dev-games/freecell-solver-6.6.0/libfreecell-so...        yes       no
# 28565      dev-games/freecell-solver-6.6.0/dbm-fc-solver        yes       no
# 28566  dev-games/freecell-solver-6.6.0/depth-dbm-fc-s...        yes       no
# 28567             dev-games/libnw-1.30.02/libnw.so.0.0.0        yes       no
# 28568  dev-games/libmt_client-0.1.98-r1/libmt_client....        yes       no
# 28570         dev-games/hdl_dump-0.9.2.20180722/hdl_dump        yes       no
# 28574  dev-games/libsmacker-1.2.0_p43/libsmacker.so.1...        yes       no
# 28585  dev-games/libmaitretarot-0.1.98-r2/libmaitreta...        yes       no
# 28586  dev-games/poker-eval-138.0/libpoker-eval.so.1.0.0        yes       no
# 28711       dev-games/physfs-3.0.2-r1/libphysfs.so.3.0.2        yes       no
# 28715                     dev-games/paklib-0.3/libpak.so        yes       no
# 28717             dev-games/KXL-1.1.7-r3/libKXL-1.1.7.so        yes       no
# 28817  dev-games/t4k-common-0.1.1-r1/libt4k_common.so...        yes       no
# 28819            dev-games/hawknl-1.68-r3/libNL.so.1.6.8        yes       no
#
#       language O_flag inlined_func                              hash x86-64
# 28548        C  [-O0]           no  f36db8b4ff4a9b15fded1847a9a58b3b    yes  \
# 28549        C  [-O0]           no  7daa0eee1a58009f8b938bdab49c2c01    yes
# 28550        C  [-O0]           no  b2e3af52ff5b6e32d69bf2c27e81a5b7    yes
# 28551        C  [-O0]           no  b18dffb2be6f63d2d3b6121faf9d0737    yes
# 28552        C  [-O0]           no  afa2e0402ea3489687abdaf22dcf8e0b    yes
# 28553        C  [-O0]           no  d58d46ae632a9f0f1c9f0b9da077ae11    yes
# 28554        C  [-O0]           no  5d25e1f3ced924411da5cdba6bfb092e    yes
# 28555        C  [-O0]           no  6f3f1631420e70584b8b48f649964ff5    yes
# 28556        C  [-O0]           no  d863c3ee3bd108996c86ea57ed9a76fd    yes
# 28557        C  [-O0]           no  05b5493533c8776f60070c9edd3240dc    yes
# 28558        C  [-O0]           no  e48d179f72de060a009c50c6aec9e9a4    yes
# 28559        C  [-O0]           no  6818ad80af00f94e471f7d8e432555cd    yes
# 28560        C  [-O0]           no  55750c9c4bb4369088cdf099b015ceeb    yes
# 28561        C  [-O0]           no  3334ee1b06489869f4e30664700ec6ae    yes
# 28562        C  [-O0]           no  86bf3edae3095cb67d0fbb6cd39c3f17    yes
# 28563        C  [-O0]           no  62ea071b7815eaff41abbb26e8d703ae    yes
# 28564        C  [-O0]          yes  95fc9b017b57c3c61e8c655729c781ea    yes
# 28565        C  [-O0]           no  ad45115372422ba8b37ae1da299f60e3    yes
# 28566        C  [-O0]           no  66a4e1c2a3d300c4cb56c10e4bfaee1b    yes
# 28567        C  [-O0]           no  44e14c94148c744c6e56ae4aa60fdf67    yes
# 28568        C  [-O0]           no  bfd4249e6cb4b8ca5dda9399573f2b23    yes
# 28570        C  [-O0]           no  b812be1928cbc675fbcbd4abad612d29    yes
# 28574        C  [-O0]           no  fd80b7c1c43b69f101a62f8c2237ec89    yes
# 28585        C  [-O0]           no  711c08f642690e502023d851ca5e682c    yes
# 28586        C  [-O0]           no  e1dcd0e276f9a5fb90306469e518f8d1    yes
# 28711        C  [-O0]           no  6eb77f7b8440251457c194a84056bd77    yes
# 28715        C  [-O0]           no  21f4e489ac43f73ffee43c02530841da    yes
# 28717        C  [-O0]           no  b34b0a6e7cb78bc40bc9dfa156a12a77    yes
# 28817        C  [-O0]           no  b16f2549256acbba815ab5a0f4957437    yes
# 28819        C  [-O0]           no  9f5ef57107d39aeeb36c2be6a9aadb4f    yes
#
#       cython  Opt
# 28548     no  -O0
# 28549     no  -O0
# 28550     no  -O0
# 28551     no  -O0
# 28552     no  -O0
# 28553     no  -O0
# 28554     no  -O0
# 28555     no  -O0
# 28556     no  -O0
# 28557     no  -O0
# 28558     no  -O0
# 28559     no  -O0
# 28560     no  -O0
# 28561     no  -O0
# 28562     no  -O0
# 28563     no  -O0
# 28564     no  -O0
# 28565     no  -O0
# 28566     no  -O0
# 28567     no  -O0
# 28568     no  -O0
# 28570     no  -O0
# 28574     no  -O0
# 28585     no  -O0
# 28586     no  -O0
# 28711     no  -O0
# 28715     no  -O0
# 28717     no  -O0
# 28817     no  -O0
# 28819     no  -O0
